# %% [markdown]
# # Assignment 2: Convolutional Neural Networks
#
# **Version Release Date**: 2023-01-29
#
# **Due Date**: Friday, Feb. 24, at 11:59pm
#
# Based on an assignment by Lisa Zhang
#
# For CSC413/2516 in Winter 2023 with Professors Jimmy Ba and Bo Wang
#
# **Submission:**
# You must submit two files through [MarkUs](https://markus.teach.cs.toronto.edu/2022-01/): a PDF file containing your writeup, titled *a2-writeup.pdf*, and your code file *a2-code.ipynb*. Your writeup must be typeset.
#
# The programming assignments are individual work. See the Course Syllabus for detailed policies.
#
# **Introduction:**
# This assignment will focus on the applications of convolutional neural networks in various image processing tasks. We will train a convolutional neural network for a task known as image colourization. Given a greyscale image, we will predict the colour at each pixel. This a difficult problem for many reasons, one of which being that it is ill-posed: for a single greyscale image, there can be multiple,  equally valid colourings.

# %% [markdown]
# # Colab FAQ and Using GPU
#
# For some basic overview and features offered in Colab notebooks, check out: [Overview of Colaboratory Features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb).
#
# You need to use the Colab GPU for this assignment by selecting:
#
# > **Runtime**   →   **Change runtime type**   →   **Hardware Accelerator: GPU**

# %% [markdown]
# # Download CIFAR and Colour dictionary
# We will use the [CIFAR-10 data set](http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz), which consists of images of size 32x32 pixels. For most of the questions we will use a subset of the dataset. To make the problem easier, we will only use the “Horse” category from this data set. Now let’s learn to colour some horses!
#
# The data loading script is included below. It can take up to a couple of minutes to download everything the first time.
#
# All files are stored at `/content/csc413/a2/data/` folder.

# %% [markdown]
# #### Helper code
# You can ignore the restart warning.

# %%
######################################################################
# Setup working directory
######################################################################
# %mkdir -p /content/csc413/a2/
# %cd /content/csc413/a2

######################################################################
# Helper functions for loading data
######################################################################
# adapted from
# https://github.com/fchollet/keras/blob/master/keras/datasets/cifar10.py

import os
import pickle
import sys
import tarfile

import numpy as np
from PIL import Image
from six.moves.urllib.request import urlretrieve


def get_file(fname, origin, untar=False, extract=False, archive_format="auto", cache_dir="data"):
    datadir = os.path.join(cache_dir)
    if not os.path.exists(datadir):
        os.makedirs(datadir)

    if untar:
        untar_fpath = os.path.join(datadir, fname)
        fpath = untar_fpath + ".tar.gz"
    else:
        fpath = os.path.join(datadir, fname)

    print("File path: %s" % fpath)
    if not os.path.exists(fpath):
        print("Downloading data from", origin)

        error_msg = "URL fetch failure on {}: {} -- {}"
        try:
            try:
                urlretrieve(origin, fpath)
            except URLError as e:
                raise Exception(error_msg.format(origin, e.errno, e.reason))
            except HTTPError as e:
                raise Exception(error_msg.format(origin, e.code, e.msg))
        except (Exception, KeyboardInterrupt) as e:
            if os.path.exists(fpath):
                os.remove(fpath)
            raise

    if untar:
        if not os.path.exists(untar_fpath):
            print("Extracting file.")
            with tarfile.open(fpath) as archive:
                archive.extractall(datadir)
        return untar_fpath

    if extract:
        _extract_archive(fpath, datadir, archive_format)

    return fpath


def load_batch(fpath, label_key="labels"):
    """Internal utility for parsing CIFAR data.
    # Arguments
        fpath: path the file to parse.
        label_key: key for label data in the retrieve
            dictionary.
    # Returns
        A tuple `(data, labels)`.
    """
    f = open(fpath, "rb")
    if sys.version_info < (3,):
        d = pickle.load(f)
    else:
        d = pickle.load(f, encoding="bytes")
        # decode utf8
        d_decoded = {}
        for k, v in d.items():
            d_decoded[k.decode("utf8")] = v
        d = d_decoded
    f.close()
    data = d["data"]
    labels = d[label_key]

    data = data.reshape(data.shape[0], 3, 32, 32)
    return data, labels


def load_cifar10(transpose=False):
    """Loads CIFAR10 dataset.
    # Returns
        Tuple of Numpy arrays: `(x_train, y_train), (x_test, y_test)`.
    """
    dirname = "cifar-10-batches-py"
    origin = "http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
    path = get_file(dirname, origin=origin, untar=True)

    num_train_samples = 50000

    x_train = np.zeros((num_train_samples, 3, 32, 32), dtype="uint8")
    y_train = np.zeros((num_train_samples,), dtype="uint8")

    for i in range(1, 6):
        fpath = os.path.join(path, "data_batch_" + str(i))
        data, labels = load_batch(fpath)
        x_train[(i - 1) * 10000 : i * 10000, :, :, :] = data
        y_train[(i - 1) * 10000 : i * 10000] = labels

    fpath = os.path.join(path, "test_batch")
    x_test, y_test = load_batch(fpath)

    y_train = np.reshape(y_train, (len(y_train), 1))
    y_test = np.reshape(y_test, (len(y_test), 1))

    if transpose:
        x_train = x_train.transpose(0, 2, 3, 1)
        x_test = x_test.transpose(0, 2, 3, 1)
    return (x_train, y_train), (x_test, y_test)
# Out:
# /content/csc413/a2

# %% [markdown]
# #### Download files
#
# This may take 1 or 2 mins for the first time.

# %%
# Download cluster centers for k-means over colours
colours_fpath = get_file(
    fname="colours", origin="http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz", untar=True
)
# Download CIFAR dataset
m = load_cifar10()
# Out:
# File path: data/colours.tar.gz
# Downloading data from http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz
# Extracting file.
# File path: data/cifar-10-batches-py.tar.gz
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Extracting file.

# %% [markdown]
# # Image Colourization as Classification
#
# We will select a subset of 24 colours and frame colourization as a pixel-wise classification problem, where we label each pixel with one of 24 colours. The 24 colours are selected using [k-means clustering](https://en.wikipedia.org/wiki/K-means_clustering) over colours, and selecting cluster centers.
#
# This was already done for you, and cluster centers are provided in http://www.cs.toronto.edu/~jba/kmeans_colour_a2.tar.gz, which was downloaded by the helper functions above. For simplicity, we will measure distance in RGB space. This is not ideal but reduces the software dependencies for this assignment.

# %% [markdown]
# ## Helper code

# %%
"""
Colourization of CIFAR-10 Horses via classification.
"""
import argparse
import math
import time

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import scipy.misc
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# from load_data import load_cifar10

HORSE_CATEGORY = 7

# %% [markdown]
# #### Data related code

# %%
def get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This function doesn't
    actually do the work, instead it splits the work into smaller
    chunks that can fit into memory, and calls helper function
    _get_rgb_cat

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    if np.shape(xs)[0] < 100:
        return _get_rgb_cat(xs)
    batch_size = 100
    nexts = []
    for i in range(0, np.shape(xs)[0], batch_size):
        next = _get_rgb_cat(xs[i : i + batch_size, :, :, :], colours)
        nexts.append(next)
    result = np.concatenate(nexts, axis=0)
    return result


def _get_rgb_cat(xs, colours):
    """
    Get colour categories given RGB values. This is done by choosing
    the colour in `colours` that is the closest (in RGB space) to
    each point in the image `xs`. This function is a little memory
    intensive, and so the size of `xs` should not be too large.

    Args:
      xs: float numpy array of RGB images in [B, C, H, W] format
      colours: numpy array of colour categories and their RGB values
    Returns:
      result: int numpy array of shape [B, 1, H, W]
    """
    num_colours = np.shape(colours)[0]
    xs = np.expand_dims(xs, 0)
    cs = np.reshape(colours, [num_colours, 1, 3, 1, 1])
    dists = np.linalg.norm(xs - cs, axis=2)  # 2 = colour axis
    cat = np.argmin(dists, axis=0)
    cat = np.expand_dims(cat, axis=1)
    return cat


def get_cat_rgb(cats, colours):
    """
    Get RGB colours given the colour categories

    Args:
      cats: integer numpy array of colour categories
      colours: numpy array of colour categories and their RGB values
    Returns:
      numpy tensor of RGB colours
    """
    return colours[cats]


def process(xs, ys, max_pixel=256.0, downsize_input=False):
    """
    Pre-process CIFAR10 images by taking only the horse category,
    shuffling, and have colour values be bound between 0 and 1

    Args:
      xs: the colour RGB pixel values
      ys: the category labels
      max_pixel: maximum pixel value in the original data
    Returns:
      xs: value normalized and shuffled colour images
      grey: greyscale images, also normalized so values are between 0 and 1
    """
    xs = xs / max_pixel
    xs = xs[np.where(ys == HORSE_CATEGORY)[0], :, :, :]
    npr.shuffle(xs)

    grey = np.mean(xs, axis=1, keepdims=True)

    if downsize_input:
        downsize_module = nn.Sequential(
            nn.AvgPool2d(2),
            nn.AvgPool2d(2),
            nn.Upsample(scale_factor=2),
            nn.Upsample(scale_factor=2),
        )
        xs_downsized = downsize_module.forward(torch.from_numpy(xs).float())
        xs_downsized = xs_downsized.data.numpy()
        return (xs, xs_downsized)
    else:
        return (xs, grey)


def get_batch(x, y, batch_size):
    """
    Generated that yields batches of data

    Args:
      x: input values
      y: output values
      batch_size: size of each batch
    Yields:
      batch_x: a batch of inputs of size at most batch_size
      batch_y: a batch of outputs of size at most batch_size
    """
    N = np.shape(x)[0]
    assert N == np.shape(y)[0]
    for i in range(0, N, batch_size):
        batch_x = x[i : i + batch_size, :, :, :]
        batch_y = y[i : i + batch_size, :, :, :]
        yield (batch_x, batch_y)

# %% [markdown]
# #### Torch helper

# %%
def get_torch_vars(xs, ys, gpu=False):
    """
    Helper function to convert numpy arrays to pytorch tensors.
    If GPU is used, move the tensors to GPU.

    Args:
      xs (float numpy tenosor): greyscale input
      ys (int numpy tenosor): categorical labels
      gpu (bool): whether to move pytorch tensor to GPU
    Returns:
      Variable(xs), Variable(ys)
    """
    xs = torch.from_numpy(xs).float()
    ys = torch.from_numpy(ys).long()
    if gpu:
        xs = xs.cuda()
        ys = ys.cuda()
    return Variable(xs), Variable(ys)


def compute_loss(criterion, outputs, labels, batch_size, num_colours):
    """
    Helper function to compute the loss. Since this is a pixelwise
    prediction task we need to reshape the output and ground truth
    tensors into a 2D tensor before passing it in to the loss criteron.

    Args:
      criterion: pytorch loss criterion
      outputs (pytorch tensor): predicted labels from the model
      labels (pytorch tensor): ground truth labels
      batch_size (int): batch size used for training
      num_colours (int): number of colour categories
    Returns:
      pytorch tensor for loss
    """
    batch = outputs.size(0)
    loss_out = outputs.transpose(1, 3).contiguous().view([batch * 32 * 32, num_colours])
    loss_lab = labels.transpose(1, 3).contiguous().view([batch * 32 * 32])
    return criterion(loss_out, loss_lab)


def run_validation_step(
    cnn,
    criterion,
    test_grey,
    test_rgb_cat,
    batch_size,
    colours,
    plotpath=None,
    visualize=True,
    downsize_input=False
):
    correct = 0.0
    total = 0.0
    losses = []
    num_colours = np.shape(colours)[0]
    for i, (xs, ys) in enumerate(get_batch(test_grey, test_rgb_cat, batch_size)):
        images, labels = get_torch_vars(xs, ys, args.gpu)
        outputs = cnn(images)

        val_loss = compute_loss(
            criterion, outputs, labels, batch_size=args.batch_size, num_colours=num_colours
        )
        losses.append(val_loss.data.item())

        _, predicted = torch.max(outputs.data, 1, keepdim=True)
        total += labels.size(0) * 32 * 32
        correct += (predicted == labels.data).sum()

    if plotpath:  # only plot if a path is provided
        plot(
            xs,
            ys,
            predicted.cpu().numpy(),
            colours,
            plotpath,
            visualize=visualize,
            compare_bilinear=downsize_input,
        )

    val_loss = np.mean(losses)
    val_acc = 100 * correct / total
    return val_loss, val_acc

# %% [markdown]
# #### Visualization

# %%
def plot(input, gtlabel, output, colours, path, visualize, compare_bilinear=False):
    """
    Generate png plots of input, ground truth, and outputs

    Args:
      input: the greyscale input to the colourization CNN
      gtlabel: the grouth truth categories for each pixel
      output: the predicted categories for each pixel
      colours: numpy array of colour categories and their RGB values
      path: output path
      visualize: display the figures inline or save the figures in path
    """
    grey = np.transpose(input[:10, :, :, :], [0, 2, 3, 1])
    gtcolor = get_cat_rgb(gtlabel[:10, 0, :, :], colours)
    predcolor = get_cat_rgb(output[:10, 0, :, :], colours)

    img_stack = [np.hstack(np.tile(grey, [1, 1, 1, 3])), np.hstack(gtcolor), np.hstack(predcolor)]

    if compare_bilinear:
        downsize_module = nn.Sequential(
            nn.AvgPool2d(2),
            nn.AvgPool2d(2),
            nn.Upsample(scale_factor=2, mode="bilinear"),
            nn.Upsample(scale_factor=2, mode="bilinear"),
        )
        gt_input = np.transpose(
            gtcolor,
            [
                0,
                3,
                1,
                2
            ],
        )
        color_bilinear = downsize_module.forward(torch.from_numpy(gt_input).float())
        color_bilinear = np.transpose(color_bilinear.data.numpy(), [0, 2, 3, 1])
        img_stack = [
            np.hstack(np.transpose(input[:10, :, :, :], [0, 2, 3, 1])),
            np.hstack(gtcolor),
            np.hstack(predcolor),
            np.hstack(color_bilinear),
        ]
    img = np.vstack(img_stack)

    plt.grid(None)
    plt.imshow(img, vmin=0.0, vmax=1.0)
    if visualize:
        plt.show()
    else:
        plt.savefig(path)


def toimage(img, cmin, cmax):
    return Image.fromarray((img.clip(cmin, cmax) * 255).astype(np.uint8))


def plot_activation(args, cnn):
    # LOAD THE COLOURS CATEGORIES
    colours = np.load(args.colours, allow_pickle=True)[0]
    num_colours = np.shape(colours)[0]

    (x_train, y_train), (x_test, y_test) = load_cifar10()
    test_rgb, test_grey = process(x_test, y_test, downsize_input=args.downsize_input)
    test_rgb_cat = get_rgb_cat(test_rgb, colours)

    # Take the idnex of the test image
    id = args.index
    outdir = "outputs/" + args.experiment_name + "/act" + str(id)
    if not os.path.exists(outdir):
        os.makedirs(outdir)
    images, labels = get_torch_vars(
        np.expand_dims(test_grey[id], 0), np.expand_dims(test_rgb_cat[id], 0)
    )
    cnn.cpu()
    outputs = cnn(images)
    _, predicted = torch.max(outputs.data, 1, keepdim=True)
    predcolor = get_cat_rgb(predicted.cpu().numpy()[0, 0, :, :], colours)
    img = predcolor
    toimage(predcolor, cmin=0, cmax=1).save(os.path.join(outdir, "output_%d.png" % id))

    if not args.downsize_input:
        img = np.tile(np.transpose(test_grey[id], [1, 2, 0]), [1, 1, 3])
    else:
        img = np.transpose(test_grey[id], [1, 2, 0])
    toimage(img, cmin=0, cmax=1).save(os.path.join(outdir, "input_%d.png" % id))

    img = np.transpose(test_rgb[id], [1, 2, 0])
    toimage(img, cmin=0, cmax=1).save(os.path.join(outdir, "input_%d_gt.png" % id))

    def add_border(img):
        return np.pad(img, 1, "constant", constant_values=1.0)

    def draw_activations(path, activation, imgwidth=4):
        img = np.vstack(
            [
                np.hstack(
                    [
                        add_border(filter)
                        for filter in activation[i * imgwidth : (i + 1) * imgwidth, :, :]
                    ]
                )
                for i in range(activation.shape[0] // imgwidth)
            ]
        )
        scipy.misc.imsave(path, img)

    for i, tensor in enumerate([cnn.out1, cnn.out2, cnn.out3, cnn.out4, cnn.out5]):
        draw_activations(
            os.path.join(outdir, "conv%d_out_%d.png" % (i + 1, id)), tensor.data.cpu().numpy()[0]
        )
    print("visualization results are saved to %s" % outdir)

# %% [markdown]
# #### Training

# %%
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self


def train(args, cnn=None):
    # Set the maximum number of threads to prevent crash in Teaching Labs
    # TODO: necessary?
    torch.set_num_threads(5)
    # Numpy random seed
    npr.seed(args.seed)

    # Save directory
    save_dir = "outputs/" + args.experiment_name

    # LOAD THE COLOURS CATEGORIES
    colours = np.load(args.colours, allow_pickle=True, encoding="bytes")[0]
    num_colours = np.shape(colours)[0]
    # INPUT CHANNEL
    num_in_channels = 1 if not args.downsize_input else 3
    # LOAD THE MODEL
    if cnn is None:
        Net = globals()[args.model]
        cnn = Net(args.kernel, args.num_filters, num_colours, num_in_channels)

    # LOSS FUNCTION
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(cnn.parameters(), lr=args.learn_rate)

    # DATA
    print("Loading data...")
    (x_train, y_train), (x_test, y_test) = load_cifar10()

    print("Transforming data...")
    train_rgb, train_grey = process(x_train, y_train, downsize_input=args.downsize_input)
    train_rgb_cat = get_rgb_cat(train_rgb, colours)
    test_rgb, test_grey = process(x_test, y_test, downsize_input=args.downsize_input)
    test_rgb_cat = get_rgb_cat(test_rgb, colours)

    # Create the outputs folder if not created already
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    print("Beginning training ...")
    if args.gpu:
        cnn.cuda()
    start = time.time()

    train_losses = []
    valid_losses = []
    valid_accs = []
    for epoch in range(args.epochs):
        # Train the Model
        cnn.train()  # Change model to 'train' mode
        losses = []
        for i, (xs, ys) in enumerate(get_batch(train_grey, train_rgb_cat, args.batch_size)):
            images, labels = get_torch_vars(xs, ys, args.gpu)
            # Forward + Backward + Optimize
            optimizer.zero_grad()
            outputs = cnn(images)

            loss = compute_loss(
                criterion, outputs, labels, batch_size=args.batch_size, num_colours=num_colours
            )
            loss.backward()
            optimizer.step()
            losses.append(loss.data.item())

        # plot training images
        if args.plot:
            _, predicted = torch.max(outputs.data, 1, keepdim=True)
            plot(
                xs,
                ys,
                predicted.cpu().numpy(),
                colours,
                save_dir + "/train_%d.png" % epoch,
                args.visualize,
                args.downsize_input,
            )

        # plot training images
        avg_loss = np.mean(losses)
        train_losses.append(avg_loss)
        time_elapsed = time.time() - start
        print(
            "Epoch [%d/%d], Loss: %.4f, Time (s): %d"
            % (epoch + 1, args.epochs, avg_loss, time_elapsed)
        )

        # Evaluate the model
        cnn.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
        val_loss, val_acc = run_validation_step(
            cnn,
            criterion,
            test_grey,
            test_rgb_cat,
            args.batch_size,
            colours,
            save_dir + "/test_%d.png" % epoch,
            args.visualize,
            args.downsize_input,
        )

        time_elapsed = time.time() - start
        valid_losses.append(val_loss)
        valid_accs.append(val_acc)
        print(
            "Epoch [%d/%d], Val Loss: %.4f, Val Acc: %.1f%%, Time(s): %.2f"
            % (epoch + 1, args.epochs, val_loss, val_acc, time_elapsed)
        )

    # Plot training curve
    plt.figure()
    plt.plot(train_losses, "ro-", label="Train")
    plt.plot(valid_losses, "go-", label="Validation")
    plt.legend()
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.savefig(save_dir + "/training_curve.png")

    if args.checkpoint:
        print("Saving model...")
        torch.save(cnn.state_dict(), args.checkpoint)

    return cnn

# %% [markdown]
# ## 4: Pooling and Upsampling

# %% [markdown]
# ### 4.1 [0.5pt] [Type 1]
#
# Complete the `PoolUpsampleNet` CNN model following the architecture described in the assignment handout.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the diagram above, we denote the number of filters as **NF**. Further layers double the number of filters, denoted as **2NF**. In the final layers, the number of filters will be equivalent to the number of colour classes, denoted as **NC**. Consequently, your constructed neural network should define the number of input/output layers with respect to the variables `num_filters` and `num_colours`, as opposed to a constant value.
#
#
# The specific modules to use are listed below. If parameters are not otherwise specified, use the default PyTorch parameters.
#
# - [`nn.Conv2d`](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html) — The number of input filters should match the second dimension of the _input_ tensor (e.g. the first `nn.Conv2d` layer has **NIC** input filters). The number of output filters should match the second dimension of the _output_ tensor (e.g. the first `nn.Conv2d` layer has **NF** output filters). Set kernel size to parameter `kernel`. Set padding to the `padding` variable included in the starter code.
# - [`nn.MaxPool2d`](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html#torch.nn.MaxPool2d) — Use `kernel_size=2` for all layers.
# - [`nn.BatchNorm2d`](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html#torch.nn.BatchNorm2d) — The number of features is specified after the hyphen in the diagram as a multiple of **NF** or **NC**.
# - [`nn.Upsample`](https://pytorch.org/docs/stable/generated/torch.nn.Upsample.html#torch.nn.Upsample) — Use `scaling_factor=2` for all layers.
# - [`nn.ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html#torch.nn.ReLU)
#
#
# We recommend grouping each block of operations (those adjacent without whitespace in the diagram) into [`nn.Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html#torch.nn.Sequential) containers. Grouping up relevant operations will allow for easier implementation of the `forward` method.

# %% [markdown]
# **ChatGPT Trace**
#
# ![4trace.jpg](data:image/jpeg;base64,...)
#
# **Critique: It did a good job interpreting the different arguments to all the layers, and gave a good example for the input/output channels in each of the layers.**

# %%
class PoolUpsampleNet(nn.Module):
    def __init__(self, kernel, num_filters, num_colours, num_in_channels):
        super().__init__()

        # Useful parameters
        padding = kernel // 2

        ############### YOUR CODE GOES HERE ###############
        block1 = nn.Sequential(
            nn.Conv2d(num_in_channels, num_filters, kernel, padding=padding),
            nn.MaxPool2d(kernel_size=2),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )

        block2 = nn.Sequential(
            nn.Conv2d(num_filters, 2 * num_filters, kernel, padding=padding),
            nn.MaxPool2d(kernel_size=2),
            nn.BatchNorm2d(2 * num_filters),
            nn.ReLU()
        )

        block3 = nn.Sequential(
            nn.Conv2d(2 * num_filters, num_filters, kernel, padding=padding),
            nn.Upsample(scale_factor=2),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )

        block4 = nn.Sequential(
            nn.Conv2d(num_filters, num_colours, kernel, padding=padding),
            nn.Upsample(scale_factor=2),
            nn.BatchNorm2d(num_colours),
            nn.ReLU()
        )

        block5 = nn.Conv2d(num_colours, num_colours, kernel, padding=padding)

        self.network = nn.Sequential(
            block1,
            block2,
            block3,
            block4,
            block5
        )
        
        ###################################################

    def forward(self, x):
        ############### YOUR CODE GOES HERE ###############
        x = self.network(x)

        return x       
        ###################################################

# %% [markdown]
# ### 4.2 [0.5pt] [Type 4]
#
# Run main training loop of `PoolUpsampleNet`. This will train the CNN for a few epochs using the cross-entropy objective. It will generate some images showing the trained result at the end. Do these results look good to you? Why or why not?

# %%
args = AttrDict()
args_dict = {
    "gpu": True,
    "valid": False,
    "checkpoint": "",
    "colours": "./data/colours/colour_kmeans24_cat7.npy",
    "model": "PoolUpsampleNet",
    "kernel": 3,
    "num_filters": 32,
    'learn_rate':0.001, 
    "batch_size": 100,
    "epochs": 25,
    "seed": 0,
    "plot": True,
    "experiment_name": "colourization_cnn",
    "visualize": False,
    "downsize_input": False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# Loading data...
# File path: data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/25], Loss: 2.4699, Time (s): 7
# Epoch [1/25], Val Loss: 2.1798, Val Acc: 25.6%, Time(s): 7.93
# Epoch [2/25], Loss: 1.9929, Time (s): 8
# Epoch [2/25], Val Loss: 1.9133, Val Acc: 33.3%, Time(s): 8.80
# Epoch [3/25], Loss: 1.8735, Time (s): 9
# Epoch [3/25], Val Loss: 1.8135, Val Acc: 35.8%, Time(s): 9.70
# Epoch [4/25], Loss: 1.8129, Time (s): 10
# Epoch [4/25], Val Loss: 1.7660, Val Acc: 36.8%, Time(s): 10.63
# Epoch [5/25], Loss: 1.7741, Time (s): 11
# Epoch [5/25], Val Loss: 1.7331, Val Acc: 37.5%, Time(s): 11.59
# Epoch [6/25], Loss: 1.7463, Time (s): 12
# Epoch [6/25], Val Loss: 1.7079, Val Acc: 38.1%, Time(s): 12.58
# Epoch [7/25], Loss: 1.7247, Time (s): 13
# Epoch [7/25], Val Loss: 1.6900, Val Acc: 38.5%, Time(s): 13.60
# Epoch [8/25], Loss: 1.7074, Time (s): 14
# Epoch [8/25], Val Loss: 1.6775, Val Acc: 38.8%, Time(s): 14.65
# Epoch [9/25], Loss: 1.6932, Time (s): 15
# Epoch [9/25], Val Loss: 1.6684, Val Acc: 39.0%, Time(s): 15.74
# Epoch [10/25], Loss: 1.6813, Time (s): 16
# Epoch [10/25], Val Loss: 1.6599, Val Acc: 39.2%, Time(s): 16.86
# Epoch [11/25], Loss: 1.6710, Time (s): 17
# Epoch [11/25], Val Loss: 1.6496, Val Acc: 39.5%, Time(s): 18.23
# Epoch [12/25], Loss: 1.6618, Time (s): 19
# Epoch [12/25], Val Loss: 1.6412, Val Acc: 39.8%, Time(s): 19.59
# Epoch [13/25], Loss: 1.6532, Time (s): 20
# Epoch [13/25], Val Loss: 1.6322, Val Acc: 40.0%, Time(s): 20.99
# Epoch [14/25], Loss: 1.6453, Time (s): 21
# Epoch [14/25], Val Loss: 1.6250, Val Acc: 40.3%, Time(s): 22.22
# Epoch [15/25], Loss: 1.6381, Time (s): 23
# Epoch [15/25], Val Loss: 1.6185, Val Acc: 40.4%, Time(s): 23.47
# Epoch [16/25], Loss: 1.6316, Time (s): 24
# Epoch [16/25], Val Loss: 1.6133, Val Acc: 40.5%, Time(s): 24.77
# Epoch [17/25], Loss: 1.6255, Time (s): 25
# Epoch [17/25], Val Loss: 1.6110, Val Acc: 40.5%, Time(s): 26.09
# Epoch [18/25], Loss: 1.6199, Time (s): 27
# Epoch [18/25], Val Loss: 1.6077, Val Acc: 40.6%, Time(s): 27.45
# Epoch [19/25], Loss: 1.6147, Time (s): 28
# Epoch [19/25], Val Loss: 1.6033, Val Acc: 40.7%, Time(s): 28.84
# Epoch [20/25], Loss: 1.6099, Time (s): 29
# Epoch [20/25], Val Loss: 1.5997, Val Acc: 40.8%, Time(s): 30.58
# Epoch [21/25], Loss: 1.6056, Time (s): 31
# Epoch [21/25], Val Loss: 1.5961, Val Acc: 40.9%, Time(s): 32.15
# Epoch [22/25], Loss: 1.6015, Time (s): 33
# Epoch [22/25], Val Loss: 1.5938, Val Acc: 40.9%, Time(s): 33.62
# Epoch [23/25], Loss: 1.5978, Time (s): 34
# Epoch [23/25], Val Loss: 1.5892, Val Acc: 41.0%, Time(s): 35.13
# Epoch [24/25], Loss: 1.5943, Time (s): 36
# Epoch [24/25], Val Loss: 1.5877, Val Acc: 41.1%, Time(s): 36.65
# Epoch [25/25], Loss: 1.5910, Time (s): 37
# Epoch [25/25], Val Loss: 1.5877, Val Acc: 41.1%, Time(s): 38.29

# %% [markdown]
# ### 4.3 [1.0pt] [Type 3]
#
# **Answer**
#
# ![image.png](data:image/png;base64,...)
#
# **Doubled**
#
# ![image.png](data:image/png;base64,...)
#
# **original**
#
# weights: $9NF*NIC + 18NF^2 + 18NF^2 + 9NF*NC + 9NC^2$
#
# outputs: $NF*(32^2 + 2 * 16^2) + 2NF*(16^2+2*8^2) + NF*(8^2+2*16^2) + NC*(16^2 + 2*32^2) + 32^2NC$
#
# connections: $(32^2*9*NF*NIC + 16^2*4*NF) + (16^2*9*2NF^2+8^2*4*2NF) + (8^2*9*2NF^2+16^2NF) + (16^2*9*NF*NC+32^2NC) + (32^2*9NC^2)$
#
# **doubled**
#
# weights: $9NF*NIC + 18NF^2 + 18NF^2 + 9NF*NC + 9NC^2$
#
# outputs: $NF*(64^2 + 2 * 32^2) + 2NF*(32^2+2*16^2) + NF*(16^2+2*32^2) + NC*(32^2 + 2*64^2) + 64^2NC$
#
# connections: $(64^2*9*NF*NIC + 32^2*4*NF) + (32^2*9*2NF^2+16^2*4*2NF) + (16^2*9*2NF^2+32^2NF) + (32^2*9*NF*NC+64^2NC) + (64^2*9NC^2)$

# %% [markdown]
# ## 5 Strided and Transposed Dilated Convolutions

# %% [markdown]
# ### 5.1 [0.5pt] [Type 1]
#
# Complete the `ConvTransposeNet` CNN model following the architecture described in the assignment handout.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# An excellent visualization of convolutions and transposed convolutions with strides can be found here: <https://github.com/vdumoulin/conv_arithmetic>.
#
# The specific modules to use are listed below. If parameters are not otherwise specified, use the default PyTorch parameters.
#
# - [`nn.Conv2d`](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html) — The number of input and output filters, and the kernel size, should be set in the same way as Section 4. For the first two `nn.Conv2d` layers, set `stride` to 2 and set `padding` to 1.
# - [`nn.BatchNorm2d`](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html#torch.nn.BatchNorm2d) — The number of features should be specified in the same way as for Section 4.
# - [`nn.ConvTranspose2d`](https://pytorch.org/docs/stable/generated/torch.nn.ConvTranspose2d.html) — The number of input filters should match the second dimension of the _input_ tensor. The number of output filters should match the second dimension of the _output_ tensor. Set `kernel_size` to parameter `kernel`. Set `stride` to 2, set `dilation` to 1, and set both `padding` and `output_padding` to 1.
# - [`nn.ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html#torch.nn.ReLU)

# %% [markdown]
# **ChatGPT Trace**
#
# ![5trace.jpg](data:image/jpeg;base64,...)
#
# **Critique: same as the previous comment, the ChatGPT provided a good example code for the implementation.**

# %%
class ConvTransposeNet(nn.Module):
    def __init__(self, kernel, num_filters, num_colours, num_in_channels):
        super().__init__()

        # Useful parameters
        stride = 2
        padding = kernel // 2
        output_padding = 1

        ############### YOUR CODE GOES HERE ##########
        block1 = nn.Sequential(
            nn.Conv2d(num_in_channels, num_filters, kernel, stride, padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )
        block2 = nn.Sequential(
            nn.Conv2d(num_filters, 2 * num_filters, kernel, stride, padding),
            nn.BatchNorm2d(2 * num_filters),
            nn.ReLU()
        )
        block3 = nn.Sequential(
            nn.ConvTranspose2d(2 * num_filters, num_filters, kernel,
                      stride, padding, output_padding,
                      dilation=1),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )
        block4 = nn.Sequential(
            nn.ConvTranspose2d(num_filters, num_colours, kernel,
                      stride, padding, output_padding,
                      dilation=1),
            nn.BatchNorm2d(num_colours),
            nn.ReLU()
        )
        block5 = nn.Conv2d(num_colours, num_colours, kernel, padding=padding)
        self.network = nn.Sequential(
            block1,
            block2,
            block3,
            block4,
            block5
        )
        ###################################################

    def forward(self, x):
        ############### YOUR CODE GOES HERE ##########
        return self.network(x)
        ###################################################

# %% [markdown]
# ### 5.2 [0.5pt] [Type 4]
#
# Train the model for at least 25 epochs using a batch size of 100 and a kernel size of 3. Plot the training curve, and include this plot in your write-up. How do the results compare to the previous model?

# %%
args = AttrDict()
args_dict = {
    "gpu": True,
    "valid": False,
    "checkpoint": "",
    "colours": "./data/colours/colour_kmeans24_cat7.npy",
    "model": "ConvTransposeNet",
    "kernel": 3,
    "num_filters": 32,
    'learn_rate':0.001, 
    "batch_size": 100,
    "epochs": 100,
    "seed": 0,
    "plot": True,
    "experiment_name": "colourization_cnn",
    "visualize": False,
    "downsize_input": False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# Loading data...
# File path: data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/100], Loss: 2.4934, Time (s): 0
# Epoch [1/100], Val Loss: 2.1046, Val Acc: 30.2%, Time(s): 0.90
# Epoch [2/100], Loss: 1.8727, Time (s): 1
# Epoch [2/100], Val Loss: 1.7603, Val Acc: 37.2%, Time(s): 1.68
# Epoch [3/100], Loss: 1.7113, Time (s): 2
# Epoch [3/100], Val Loss: 1.6437, Val Acc: 40.4%, Time(s): 2.48
# Epoch [4/100], Loss: 1.6267, Time (s): 3
# Epoch [4/100], Val Loss: 1.5696, Val Acc: 42.3%, Time(s): 3.33
# Epoch [5/100], Loss: 1.5659, Time (s): 4
# Epoch [5/100], Val Loss: 1.5116, Val Acc: 44.0%, Time(s): 4.20
# Epoch [6/100], Loss: 1.5166, Time (s): 4
# Epoch [6/100], Val Loss: 1.4641, Val Acc: 45.5%, Time(s): 5.12
# Epoch [7/100], Loss: 1.4759, Time (s): 5
# Epoch [7/100], Val Loss: 1.4251, Val Acc: 46.6%, Time(s): 6.05
# Epoch [8/100], Loss: 1.4417, Time (s): 6
# Epoch [8/100], Val Loss: 1.3942, Val Acc: 47.5%, Time(s): 7.02
# Epoch [9/100], Loss: 1.4125, Time (s): 7
# Epoch [9/100], Val Loss: 1.3657, Val Acc: 48.4%, Time(s): 8.01
# Epoch [10/100], Loss: 1.3871, Time (s): 8
# Epoch [10/100], Val Loss: 1.3414, Val Acc: 49.1%, Time(s): 9.04
# Epoch [11/100], Loss: 1.3643, Time (s): 9
# Epoch [11/100], Val Loss: 1.3205, Val Acc: 49.6%, Time(s): 10.10
# Epoch [12/100], Loss: 1.3436, Time (s): 11
# Epoch [12/100], Val Loss: 1.3004, Val Acc: 50.2%, Time(s): 11.45
# Epoch [13/100], Loss: 1.3248, Time (s): 12
# Epoch [13/100], Val Loss: 1.2795, Val Acc: 50.9%, Time(s): 12.70
# Epoch [14/100], Loss: 1.3078, Time (s): 13
# Epoch [14/100], Val Loss: 1.2630, Val Acc: 51.4%, Time(s): 13.86
# Epoch [15/100], Loss: 1.2922, Time (s): 14
# Epoch [15/100], Val Loss: 1.2445, Val Acc: 52.0%, Time(s): 15.05
# Epoch [16/100], Loss: 1.2782, Time (s): 15
# Epoch [16/100], Val Loss: 1.2311, Val Acc: 52.5%, Time(s): 16.27
# Epoch [17/100], Loss: 1.2655, Time (s): 17
# Epoch [17/100], Val Loss: 1.2193, Val Acc: 52.8%, Time(s): 17.53
# Epoch [18/100], Loss: 1.2540, Time (s): 18
# Epoch [18/100], Val Loss: 1.2069, Val Acc: 53.2%, Time(s): 18.81
# Epoch [19/100], Loss: 1.2435, Time (s): 19
# Epoch [19/100], Val Loss: 1.1980, Val Acc: 53.5%, Time(s): 20.12
# Epoch [20/100], Loss: 1.2338, Time (s): 21
# Epoch [20/100], Val Loss: 1.1870, Val Acc: 53.9%, Time(s): 21.45
# Epoch [21/100], Loss: 1.2250, Time (s): 22
# Epoch [21/100], Val Loss: 1.1808, Val Acc: 54.0%, Time(s): 23.04
# Epoch [22/100], Loss: 1.2169, Time (s): 24
# Epoch [22/100], Val Loss: 1.1710, Val Acc: 54.4%, Time(s): 24.73
# Epoch [23/100], Loss: 1.2093, Time (s): 25
# Epoch [23/100], Val Loss: 1.1624, Val Acc: 54.7%, Time(s): 26.20
# Epoch [24/100], Loss: 1.2022, Time (s): 27
# Epoch [24/100], Val Loss: 1.1567, Val Acc: 54.8%, Time(s): 27.64
# Epoch [25/100], Loss: 1.1956, Time (s): 28
# Epoch [25/100], Val Loss: 1.1539, Val Acc: 54.9%, Time(s): 29.12
# Epoch [26/100], Loss: 1.1893, Time (s): 30
# Epoch [26/100], Val Loss: 1.1454, Val Acc: 55.2%, Time(s): 30.64
# Epoch [27/100], Loss: 1.1835, Time (s): 31
# Epoch [27/100], Val Loss: 1.1422, Val Acc: 55.2%, Time(s): 32.21
# Epoch [28/100], Loss: 1.1780, Time (s): 33
# Epoch [28/100], Val Loss: 1.1358, Val Acc: 55.4%, Time(s): 33.80
# Epoch [29/100], Loss: 1.1728, Time (s): 35
# Epoch [29/100], Val Loss: 1.1312, Val Acc: 55.6%, Time(s): 35.82
# Epoch [30/100], Loss: 1.1679, Time (s): 36
# Epoch [30/100], Val Loss: 1.1245, Val Acc: 55.8%, Time(s): 37.56
# Epoch [31/100], Loss: 1.1632, Time (s): 38
# Epoch [31/100], Val Loss: 1.1241, Val Acc: 55.8%, Time(s): 39.21
# Epoch [32/100], Loss: 1.1588, Time (s): 40
# Epoch [32/100], Val Loss: 1.1156, Val Acc: 56.1%, Time(s): 40.90
# Epoch [33/100], Loss: 1.1547, Time (s): 42
# Epoch [33/100], Val Loss: 1.1161, Val Acc: 56.0%, Time(s): 42.66
# Epoch [34/100], Loss: 1.1507, Time (s): 43
# Epoch [34/100], Val Loss: 1.1076, Val Acc: 56.3%, Time(s): 44.42
# Epoch [35/100], Loss: 1.1469, Time (s): 45
# Epoch [35/100], Val Loss: 1.1108, Val Acc: 56.2%, Time(s): 46.21
# Epoch [36/100], Loss: 1.1434, Time (s): 47
# Epoch [36/100], Val Loss: 1.1118, Val Acc: 56.1%, Time(s): 48.59
# Epoch [37/100], Loss: 1.1399, Time (s): 49
# Epoch [37/100], Val Loss: 1.1026, Val Acc: 56.5%, Time(s): 50.52
# Epoch [38/100], Loss: 1.1366, Time (s): 51
# Epoch [38/100], Val Loss: 1.0958, Val Acc: 56.7%, Time(s): 52.40
# Epoch [39/100], Loss: 1.1335, Time (s): 53
# Epoch [39/100], Val Loss: 1.0944, Val Acc: 56.7%, Time(s): 54.30
# Epoch [40/100], Loss: 1.1304, Time (s): 55
# Epoch [40/100], Val Loss: 1.0909, Val Acc: 56.7%, Time(s): 56.30
# Epoch [41/100], Loss: 1.1275, Time (s): 57
# Epoch [41/100], Val Loss: 1.0882, Val Acc: 56.8%, Time(s): 58.24
# Epoch [42/100], Loss: 1.1247, Time (s): 59
# Epoch [42/100], Val Loss: 1.0869, Val Acc: 56.9%, Time(s): 60.88
# Epoch [43/100], Loss: 1.1220, Time (s): 62
# Epoch [43/100], Val Loss: 1.0842, Val Acc: 57.0%, Time(s): 63.00
# Epoch [44/100], Loss: 1.1194, Time (s): 64
# Epoch [44/100], Val Loss: 1.0873, Val Acc: 56.9%, Time(s): 65.06
# Epoch [45/100], Loss: 1.1169, Time (s): 66
# Epoch [45/100], Val Loss: 1.0807, Val Acc: 57.1%, Time(s): 67.13
# Epoch [46/100], Loss: 1.1145, Time (s): 68
# Epoch [46/100], Val Loss: 1.0741, Val Acc: 57.3%, Time(s): 69.23
# Epoch [47/100], Loss: 1.1121, Time (s): 70
# Epoch [47/100], Val Loss: 1.0759, Val Acc: 57.2%, Time(s): 71.60
# Epoch [48/100], Loss: 1.1098, Time (s): 73
# Epoch [48/100], Val Loss: 1.0728, Val Acc: 57.4%, Time(s): 74.13
# Epoch [49/100], Loss: 1.1075, Time (s): 75
# Epoch [49/100], Val Loss: 1.0700, Val Acc: 57.4%, Time(s): 76.40
# Epoch [50/100], Loss: 1.1054, Time (s): 77
# Epoch [50/100], Val Loss: 1.0703, Val Acc: 57.3%, Time(s): 78.65
# Epoch [51/100], Loss: 1.1033, Time (s): 80
# Epoch [51/100], Val Loss: 1.0661, Val Acc: 57.5%, Time(s): 80.92
# Epoch [52/100], Loss: 1.1012, Time (s): 82
# Epoch [52/100], Val Loss: 1.0634, Val Acc: 57.6%, Time(s): 83.38
# Epoch [53/100], Loss: 1.0992, Time (s): 85
# Epoch [53/100], Val Loss: 1.0679, Val Acc: 57.4%, Time(s): 86.19
# Epoch [54/100], Loss: 1.0973, Time (s): 87
# Epoch [54/100], Val Loss: 1.0647, Val Acc: 57.5%, Time(s): 88.66
# Epoch [55/100], Loss: 1.0955, Time (s): 90
# Epoch [55/100], Val Loss: 1.0582, Val Acc: 57.8%, Time(s): 91.12
# Epoch [56/100], Loss: 1.0937, Time (s): 92
# Epoch [56/100], Val Loss: 1.0574, Val Acc: 57.8%, Time(s): 93.62
# Epoch [57/100], Loss: 1.0919, Time (s): 95
# Epoch [57/100], Val Loss: 1.0521, Val Acc: 57.9%, Time(s): 96.65
# Epoch [58/100], Loss: 1.0902, Time (s): 98
# Epoch [58/100], Val Loss: 1.0525, Val Acc: 57.9%, Time(s): 99.26
# Epoch [59/100], Loss: 1.0886, Time (s): 100
# Epoch [59/100], Val Loss: 1.0528, Val Acc: 57.9%, Time(s): 101.90
# Epoch [60/100], Loss: 1.0869, Time (s): 103
# Epoch [60/100], Val Loss: 1.0492, Val Acc: 58.0%, Time(s): 104.52
# Epoch [61/100], Loss: 1.0854, Time (s): 106
# Epoch [61/100], Val Loss: 1.0491, Val Acc: 58.0%, Time(s): 107.19
# Epoch [62/100], Loss: 1.0839, Time (s): 109
# Epoch [62/100], Val Loss: 1.0485, Val Acc: 58.1%, Time(s): 111.26
# Epoch [63/100], Loss: 1.0824, Time (s): 112
# Epoch [63/100], Val Loss: 1.0487, Val Acc: 58.1%, Time(s): 113.99
# Epoch [64/100], Loss: 1.0809, Time (s): 115
# Epoch [64/100], Val Loss: 1.0443, Val Acc: 58.2%, Time(s): 116.75
# Epoch [65/100], Loss: 1.0795, Time (s): 118
# Epoch [65/100], Val Loss: 1.0454, Val Acc: 58.1%, Time(s): 119.50
# Epoch [66/100], Loss: 1.0781, Time (s): 121
# Epoch [66/100], Val Loss: 1.0407, Val Acc: 58.3%, Time(s): 122.77
# Epoch [67/100], Loss: 1.0768, Time (s): 124
# Epoch [67/100], Val Loss: 1.0429, Val Acc: 58.2%, Time(s): 125.66
# Epoch [68/100], Loss: 1.0755, Time (s): 127
# Epoch [68/100], Val Loss: 1.0396, Val Acc: 58.3%, Time(s): 128.46
# Epoch [69/100], Loss: 1.0742, Time (s): 130
# Epoch [69/100], Val Loss: 1.0354, Val Acc: 58.4%, Time(s): 131.32
# Epoch [70/100], Loss: 1.0730, Time (s): 133
# Epoch [70/100], Val Loss: 1.0338, Val Acc: 58.5%, Time(s): 134.62
# Epoch [71/100], Loss: 1.0718, Time (s): 136
# Epoch [71/100], Val Loss: 1.0314, Val Acc: 58.6%, Time(s): 137.67
# Epoch [72/100], Loss: 1.0706, Time (s): 139
# Epoch [72/100], Val Loss: 1.0327, Val Acc: 58.6%, Time(s): 140.66
# Epoch [73/100], Loss: 1.0694, Time (s): 142
# Epoch [73/100], Val Loss: 1.0284, Val Acc: 58.7%, Time(s): 143.69
# Epoch [74/100], Loss: 1.0682, Time (s): 145
# Epoch [74/100], Val Loss: 1.0306, Val Acc: 58.6%, Time(s): 147.37
# Epoch [75/100], Loss: 1.0671, Time (s): 149
# Epoch [75/100], Val Loss: 1.0247, Val Acc: 58.9%, Time(s): 150.44
# Epoch [76/100], Loss: 1.0660, Time (s): 152
# Epoch [76/100], Val Loss: 1.0242, Val Acc: 58.8%, Time(s): 153.49
# Epoch [77/100], Loss: 1.0650, Time (s): 155
# Epoch [77/100], Val Loss: 1.0209, Val Acc: 58.9%, Time(s): 156.61
# Epoch [78/100], Loss: 1.0639, Time (s): 158
# Epoch [78/100], Val Loss: 1.0311, Val Acc: 58.5%, Time(s): 160.43
# Epoch [79/100], Loss: 1.0629, Time (s): 162
# Epoch [79/100], Val Loss: 1.0242, Val Acc: 58.9%, Time(s): 163.60
# Epoch [80/100], Loss: 1.0619, Time (s): 165
# Epoch [80/100], Val Loss: 1.0224, Val Acc: 58.9%, Time(s): 166.80
# Epoch [81/100], Loss: 1.0609, Time (s): 168
# Epoch [81/100], Val Loss: 1.0218, Val Acc: 58.8%, Time(s): 170.19
# Epoch [82/100], Loss: 1.0599, Time (s): 172
# Epoch [82/100], Val Loss: 1.0204, Val Acc: 58.9%, Time(s): 173.82
# Epoch [83/100], Loss: 1.0590, Time (s): 175
# Epoch [83/100], Val Loss: 1.0210, Val Acc: 58.9%, Time(s): 177.21
# Epoch [84/100], Loss: 1.0581, Time (s): 179
# Epoch [84/100], Val Loss: 1.0171, Val Acc: 59.0%, Time(s): 180.55
# Epoch [85/100], Loss: 1.0572, Time (s): 182
# Epoch [85/100], Val Loss: 1.0116, Val Acc: 59.2%, Time(s): 184.57
# Epoch [86/100], Loss: 1.0563, Time (s): 186
# Epoch [86/100], Val Loss: 1.0148, Val Acc: 59.2%, Time(s): 187.97
# Epoch [87/100], Loss: 1.0554, Time (s): 189
# Epoch [87/100], Val Loss: 1.0149, Val Acc: 59.1%, Time(s): 191.37
# Epoch [88/100], Loss: 1.0545, Time (s): 193
# Epoch [88/100], Val Loss: 1.0144, Val Acc: 59.1%, Time(s): 195.15
# Epoch [89/100], Loss: 1.0537, Time (s): 197
# Epoch [89/100], Val Loss: 1.0073, Val Acc: 59.4%, Time(s): 198.74
# Epoch [90/100], Loss: 1.0529, Time (s): 200
# Epoch [90/100], Val Loss: 1.0090, Val Acc: 59.3%, Time(s): 202.25
# Epoch [91/100], Loss: 1.0521, Time (s): 204
# Epoch [91/100], Val Loss: 1.0141, Val Acc: 59.1%, Time(s): 205.78
# Epoch [92/100], Loss: 1.0513, Time (s): 208
# Epoch [92/100], Val Loss: 1.0119, Val Acc: 59.2%, Time(s): 210.03
# Epoch [93/100], Loss: 1.0505, Time (s): 212
# Epoch [93/100], Val Loss: 1.0052, Val Acc: 59.4%, Time(s): 213.63
# Epoch [94/100], Loss: 1.0497, Time (s): 215
# Epoch [94/100], Val Loss: 1.0079, Val Acc: 59.4%, Time(s): 217.28
# Epoch [95/100], Loss: 1.0489, Time (s): 219
# Epoch [95/100], Val Loss: 1.0114, Val Acc: 59.2%, Time(s): 221.62
# Epoch [96/100], Loss: 1.0482, Time (s): 223
# Epoch [96/100], Val Loss: 1.0024, Val Acc: 59.5%, Time(s): 225.29
# Epoch [97/100], Loss: 1.0475, Time (s): 227
# Epoch [97/100], Val Loss: 1.0049, Val Acc: 59.5%, Time(s): 229.02
# Epoch [98/100], Loss: 1.0467, Time (s): 231
# Epoch [98/100], Val Loss: 1.0087, Val Acc: 59.3%, Time(s): 233.45
# Epoch [99/100], Loss: 1.0460, Time (s): 235
# Epoch [99/100], Val Loss: 1.0091, Val Acc: 59.2%, Time(s): 237.24
# Epoch [100/100], Loss: 1.0453, Time (s): 239
# Epoch [100/100], Val Loss: 1.0094, Val Acc: 59.3%, Time(s): 241.15

# %% [markdown]
# ### 5.3 – 5.5
#
# **5.3**
#
# The validation error of Transposed at $25^{th}$ epoch is smaller.
#
# | $25^{th}$ epoch  | Val Loss | Val Acc |
# |------------------|----------|---------|
# | PoolUpsampleNet  | 1.5877   | 41.1%   |
# | ConvTransposeNet | 1.1539   | 54.9%   |
#
# **5.4**
#
#
#
# |          | $1^{st}$ occurrence of     |                                                              |
# | -------- | -------------------------- | ------------------------------------------------------------ |
# |          | *padding* in Conv2d        | *output_padding* and *padding* in ConvTranspose2d        |
# | kernel=4 | 1                          | $(\text{output padding} - 2 * \text{padding}) = -2$, e.g. 0/2 and 1/2 |
# | kernel=5 | 2                          | $(\text{output padding} - 2 * \text{padding}) = -3$, e.g. 1 and 2       |
# |          | **$2^{nd}$ occurrence of** |                                                              |
# |          | padding in Conv2d          | *padding* and *output_padding* in ConvTranspose2d        |
# | kernel=4 | 1                          | $(\text{output padding} - 2 * \text{padding}) = -2$          |
# | kernel=5 | 2                          | $(\text{output padding} - 2 * \text{padding}) = -3$          |

# %% [markdown]
# ## 6 Skip Connections
#
#
# A skip connection in a neural network is a connection which skips one or more layer and connects
# to a later layer. We will introduce skip connections to our previous model.

# %% [markdown]
# ### 6.1 [0.5pt] [Type 1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this question, we will be adding a skip connection from the first layer to the last, second layer to the second last, etc. That is, the final convolution should have both the output of the previous layer and the initial greyscale input as input. This type of skip-connection is introduced by [Ronneberger et al.[2015]](https://arxiv.org/abs/1505.04597), and is called a ”UNet”.
#
# Just like the `ConvTransposeNet` class that you have completed in the previous part, complete the `__init__` and `forward` methods methods of the `UNet` class below.
#
# Hint: You will need to use the function `torch.cat`.

# %% [markdown]
# **ChatGPT Trace**
#
# ![6trace.jpg](data:image/jpeg;base64,...)
#
# **Critique: ChatGPT provides an good reference for organizing layers into blocks. However, for the skip connections, it failed to concatenate two outputs in the correct axis. This answer can be used as a reference.**

# %%
class UNet(nn.Module):
    def __init__(self, kernel, num_filters, num_colours, num_in_channels):
        super().__init__()

        # Useful parameters
        stride = 2
        padding = kernel // 2
        output_padding = 1

        ############### YOUR CODE GOES HERE ##########
        self.block1 = nn.Sequential(
            nn.Conv2d(num_in_channels, num_filters, kernel, stride, padding),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )
        self.block2 = nn.Sequential(
            nn.Conv2d(num_filters, 2 * num_filters, kernel, stride, padding),
            nn.BatchNorm2d(2 * num_filters),
            nn.ReLU()
        )
        self.block3 = nn.Sequential(
            nn.ConvTranspose2d(2 * num_filters, num_filters, kernel,
                      stride, padding, output_padding,
                      dilation=1),
            nn.BatchNorm2d(num_filters),
            nn.ReLU()
        )
        self.block4 = nn.Sequential(
            nn.ConvTranspose2d(2 * num_filters, num_colours, kernel,
                      stride, padding, output_padding,
                      dilation=1),
            nn.BatchNorm2d(num_colours),
            nn.ReLU()
        )
        self.block5 = nn.Conv2d(num_colours + num_in_channels, num_colours, kernel, padding=padding)
        ###################################################

    def forward(self, x):
        ############### YOUR CODE GOES HERE ##########
        x1 = self.block1(x)
        x2 = self.block2(x1)
        x3 = torch.cat((x1, self.block3(x2)), dim=1)
        x4 = torch.cat((x, self.block4(x3)), dim=1)
        x5 = self.block5(x4)
        return x5
        ###################################################

# %% [markdown]
# ### 6.2 [0.5pt] [Type 4]
#
# Train the model for at least 25 epochs using a batch size of 100 and a kernel size of 3. Plot the training curve, and include this plot in your write-up.

# %%
args = AttrDict()
args_dict = {
    "gpu": True,
    "valid": False,
    "checkpoint": "",
    "colours": "./data/colours/colour_kmeans24_cat7.npy",
    "model": "UNet",
    "kernel": 3,
    "num_filters": 32,
    'learn_rate':0.001, 
    "batch_size": 100,
    "epochs": 100,
    "seed": 0,
    "plot": True,
    "experiment_name": "colourization_cnn",
    "visualize": False,
    "downsize_input": False,
}
args.update(args_dict)
cnn = train(args)
# Out:
# Loading data...
# File path: data/cifar-10-batches-py.tar.gz
# Transforming data...
# Beginning training ...
# Epoch [1/100], Loss: 2.3876, Time (s): 0
# Epoch [1/100], Val Loss: 2.0356, Val Acc: 30.3%, Time(s): 1.02
# Epoch [2/100], Loss: 1.7943, Time (s): 1
# Epoch [2/100], Val Loss: 1.6880, Val Acc: 39.5%, Time(s): 1.85
# Epoch [3/100], Loss: 1.6284, Time (s): 2
# Epoch [3/100], Val Loss: 1.5676, Val Acc: 42.6%, Time(s): 2.72
# Epoch [4/100], Loss: 1.5404, Time (s): 3
# Epoch [4/100], Val Loss: 1.4917, Val Acc: 44.8%, Time(s): 3.63
# Epoch [5/100], Loss: 1.4759, Time (s): 4
# Epoch [5/100], Val Loss: 1.4291, Val Acc: 46.7%, Time(s): 4.56
# Epoch [6/100], Loss: 1.4239, Time (s): 5
# Epoch [6/100], Val Loss: 1.3784, Val Acc: 48.4%, Time(s): 5.60
# Epoch [7/100], Loss: 1.3813, Time (s): 6
# Epoch [7/100], Val Loss: 1.3372, Val Acc: 49.8%, Time(s): 6.79
# Epoch [8/100], Loss: 1.3453, Time (s): 7
# Epoch [8/100], Val Loss: 1.2986, Val Acc: 51.1%, Time(s): 7.89
# Epoch [9/100], Loss: 1.3144, Time (s): 8
# Epoch [9/100], Val Loss: 1.2687, Val Acc: 52.0%, Time(s): 8.96
# Epoch [10/100], Loss: 1.2878, Time (s): 9
# Epoch [10/100], Val Loss: 1.2414, Val Acc: 53.0%, Time(s): 10.06
# Epoch [11/100], Loss: 1.2646, Time (s): 10
# Epoch [11/100], Val Loss: 1.2168, Val Acc: 53.8%, Time(s): 11.18
# Epoch [12/100], Loss: 1.2442, Time (s): 12
# Epoch [12/100], Val Loss: 1.1957, Val Acc: 54.5%, Time(s): 12.34
# Epoch [13/100], Loss: 1.2264, Time (s): 13
# Epoch [13/100], Val Loss: 1.1807, Val Acc: 54.9%, Time(s): 13.54
# Epoch [14/100], Loss: 1.2106, Time (s): 14
# Epoch [14/100], Val Loss: 1.1653, Val Acc: 55.3%, Time(s): 14.78
# Epoch [15/100], Loss: 1.1965, Time (s): 15
# Epoch [15/100], Val Loss: 1.1474, Val Acc: 55.9%, Time(s): 16.03
# Epoch [16/100], Loss: 1.1838, Time (s): 16
# Epoch [16/100], Val Loss: 1.1363, Val Acc: 56.2%, Time(s): 17.32
# Epoch [17/100], Loss: 1.1725, Time (s): 18
# Epoch [17/100], Val Loss: 1.1236, Val Acc: 56.6%, Time(s): 18.95
# Epoch [18/100], Loss: 1.1622, Time (s): 19
# Epoch [18/100], Val Loss: 1.1153, Val Acc: 56.8%, Time(s): 20.35
# Epoch [19/100], Loss: 1.1529, Time (s): 21
# Epoch [19/100], Val Loss: 1.1054, Val Acc: 57.0%, Time(s): 21.73
# Epoch [20/100], Loss: 1.1442, Time (s): 22
# Epoch [20/100], Val Loss: 1.0964, Val Acc: 57.3%, Time(s): 23.15
# Epoch [21/100], Loss: 1.1364, Time (s): 24
# Epoch [21/100], Val Loss: 1.0912, Val Acc: 57.5%, Time(s): 24.59
# Epoch [22/100], Loss: 1.1291, Time (s): 25
# Epoch [22/100], Val Loss: 1.0828, Val Acc: 57.7%, Time(s): 26.07
# Epoch [23/100], Loss: 1.1224, Time (s): 27
# Epoch [23/100], Val Loss: 1.0785, Val Acc: 57.8%, Time(s): 27.57
# Epoch [24/100], Loss: 1.1160, Time (s): 28
# Epoch [24/100], Val Loss: 1.0692, Val Acc: 58.1%, Time(s): 29.12
# Epoch [25/100], Loss: 1.1102, Time (s): 30
# Epoch [25/100], Val Loss: 1.0654, Val Acc: 58.2%, Time(s): 31.09
# Epoch [26/100], Loss: 1.1046, Time (s): 32
# Epoch [26/100], Val Loss: 1.0596, Val Acc: 58.3%, Time(s): 32.76
# Epoch [27/100], Loss: 1.0995, Time (s): 33
# Epoch [27/100], Val Loss: 1.0529, Val Acc: 58.5%, Time(s): 34.36
# Epoch [28/100], Loss: 1.0947, Time (s): 35
# Epoch [28/100], Val Loss: 1.0485, Val Acc: 58.6%, Time(s): 35.98
# Epoch [29/100], Loss: 1.0900, Time (s): 37
# Epoch [29/100], Val Loss: 1.0440, Val Acc: 58.8%, Time(s): 37.64
# Epoch [30/100], Loss: 1.0858, Time (s): 38
# Epoch [30/100], Val Loss: 1.0407, Val Acc: 58.8%, Time(s): 39.34
# Epoch [31/100], Loss: 1.0819, Time (s): 40
# Epoch [31/100], Val Loss: 1.0387, Val Acc: 58.9%, Time(s): 41.03
# Epoch [32/100], Loss: 1.0780, Time (s): 42
# Epoch [32/100], Val Loss: 1.0362, Val Acc: 58.9%, Time(s): 43.09
# Epoch [33/100], Loss: 1.0743, Time (s): 44
# Epoch [33/100], Val Loss: 1.0291, Val Acc: 59.1%, Time(s): 44.98
# Epoch [34/100], Loss: 1.0709, Time (s): 46
# Epoch [34/100], Val Loss: 1.0282, Val Acc: 59.2%, Time(s): 46.77
# Epoch [35/100], Loss: 1.0677, Time (s): 47
# Epoch [35/100], Val Loss: 1.0271, Val Acc: 59.2%, Time(s): 48.58
# Epoch [36/100], Loss: 1.0646, Time (s): 49
# Epoch [36/100], Val Loss: 1.0210, Val Acc: 59.3%, Time(s): 50.46
# Epoch [37/100], Loss: 1.0617, Time (s): 51
# Epoch [37/100], Val Loss: 1.0216, Val Acc: 59.3%, Time(s): 52.35
# Epoch [38/100], Loss: 1.0590, Time (s): 53
# Epoch [38/100], Val Loss: 1.0186, Val Acc: 59.3%, Time(s): 54.42
# Epoch [39/100], Loss: 1.0564, Time (s): 56
# Epoch [39/100], Val Loss: 1.0187, Val Acc: 59.3%, Time(s): 57.17
# Epoch [40/100], Loss: 1.0539, Time (s): 58
# Epoch [40/100], Val Loss: 1.0193, Val Acc: 59.3%, Time(s): 59.37
# Epoch [41/100], Loss: 1.0515, Time (s): 60
# Epoch [41/100], Val Loss: 1.0161, Val Acc: 59.3%, Time(s): 61.37
# Epoch [42/100], Loss: 1.0493, Time (s): 62
# Epoch [42/100], Val Loss: 1.0116, Val Acc: 59.4%, Time(s): 63.40
# Epoch [43/100], Loss: 1.0471, Time (s): 64
# Epoch [43/100], Val Loss: 1.0113, Val Acc: 59.4%, Time(s): 65.45
# Epoch [44/100], Loss: 1.0449, Time (s): 66
# Epoch [44/100], Val Loss: 1.0101, Val Acc: 59.4%, Time(s): 67.53
# Epoch [45/100], Loss: 1.0430, Time (s): 69
# Epoch [45/100], Val Loss: 1.0098, Val Acc: 59.4%, Time(s): 70.32
# Epoch [46/100], Loss: 1.0411, Time (s): 71
# Epoch [46/100], Val Loss: 1.0053, Val Acc: 59.6%, Time(s): 72.56
# Epoch [47/100], Loss: 1.0392, Time (s): 73
# Epoch [47/100], Val Loss: 1.0063, Val Acc: 59.4%, Time(s): 74.77
# Epoch [48/100], Loss: 1.0373, Time (s): 76
# Epoch [48/100], Val Loss: 1.0032, Val Acc: 59.6%, Time(s): 76.98
# Epoch [49/100], Loss: 1.0356, Time (s): 78
# Epoch [49/100], Val Loss: 1.0004, Val Acc: 59.7%, Time(s): 79.22
# Epoch [50/100], Loss: 1.0339, Time (s): 80
# Epoch [50/100], Val Loss: 0.9977, Val Acc: 59.8%, Time(s): 82.07
# Epoch [51/100], Loss: 1.0322, Time (s): 83
# Epoch [51/100], Val Loss: 0.9961, Val Acc: 59.9%, Time(s): 84.50
# Epoch [52/100], Loss: 1.0306, Time (s): 85
# Epoch [52/100], Val Loss: 0.9975, Val Acc: 59.8%, Time(s): 86.84
# Epoch [53/100], Loss: 1.0290, Time (s): 88
# Epoch [53/100], Val Loss: 0.9960, Val Acc: 59.8%, Time(s): 89.24
# Epoch [54/100], Loss: 1.0275, Time (s): 90
# Epoch [54/100], Val Loss: 0.9941, Val Acc: 59.8%, Time(s): 91.72
# Epoch [55/100], Loss: 1.0260, Time (s): 93
# Epoch [55/100], Val Loss: 0.9939, Val Acc: 59.8%, Time(s): 94.90
# Epoch [56/100], Loss: 1.0246, Time (s): 96
# Epoch [56/100], Val Loss: 0.9913, Val Acc: 59.9%, Time(s): 97.42
# Epoch [57/100], Loss: 1.0233, Time (s): 98
# Epoch [57/100], Val Loss: 0.9919, Val Acc: 59.8%, Time(s): 99.97
# Epoch [58/100], Loss: 1.0220, Time (s): 101
# Epoch [58/100], Val Loss: 0.9940, Val Acc: 59.8%, Time(s): 102.53
# Epoch [59/100], Loss: 1.0207, Time (s): 104
# Epoch [59/100], Val Loss: 0.9891, Val Acc: 59.9%, Time(s): 105.46
# Epoch [60/100], Loss: 1.0194, Time (s): 107
# Epoch [60/100], Val Loss: 0.9901, Val Acc: 59.9%, Time(s): 108.97
# Epoch [61/100], Loss: 1.0182, Time (s): 110
# Epoch [61/100], Val Loss: 0.9890, Val Acc: 60.0%, Time(s): 111.68
# Epoch [62/100], Loss: 1.0170, Time (s): 113
# Epoch [62/100], Val Loss: 0.9865, Val Acc: 60.0%, Time(s): 114.45
# Epoch [63/100], Loss: 1.0158, Time (s): 116
# Epoch [63/100], Val Loss: 0.9863, Val Acc: 60.0%, Time(s): 117.33
# Epoch [64/100], Loss: 1.0146, Time (s): 119
# Epoch [64/100], Val Loss: 0.9846, Val Acc: 60.1%, Time(s): 120.43
# Epoch [65/100], Loss: 1.0135, Time (s): 122
# Epoch [65/100], Val Loss: 0.9848, Val Acc: 60.1%, Time(s): 123.23
# Epoch [66/100], Loss: 1.0124, Time (s): 124
# Epoch [66/100], Val Loss: 0.9830, Val Acc: 60.1%, Time(s): 126.10
# Epoch [67/100], Loss: 1.0114, Time (s): 127
# Epoch [67/100], Val Loss: 0.9834, Val Acc: 60.1%, Time(s): 128.99
# Epoch [68/100], Loss: 1.0104, Time (s): 131
# Epoch [68/100], Val Loss: 0.9824, Val Acc: 60.1%, Time(s): 132.31
# Epoch [69/100], Loss: 1.0095, Time (s): 134
# Epoch [69/100], Val Loss: 0.9827, Val Acc: 60.0%, Time(s): 135.24
# Epoch [70/100], Loss: 1.0086, Time (s): 136
# Epoch [70/100], Val Loss: 0.9819, Val Acc: 60.1%, Time(s): 138.16
# Epoch [71/100], Loss: 1.0077, Time (s): 139
# Epoch [71/100], Val Loss: 0.9810, Val Acc: 60.1%, Time(s): 141.22
# Epoch [72/100], Loss: 1.0067, Time (s): 143
# Epoch [72/100], Val Loss: 0.9797, Val Acc: 60.1%, Time(s): 144.73
# Epoch [73/100], Loss: 1.0057, Time (s): 146
# Epoch [73/100], Val Loss: 0.9793, Val Acc: 60.2%, Time(s): 147.81
# Epoch [74/100], Loss: 1.0048, Time (s): 149
# Epoch [74/100], Val Loss: 0.9745, Val Acc: 60.3%, Time(s): 150.91
# Epoch [75/100], Loss: 1.0039, Time (s): 152
# Epoch [75/100], Val Loss: 0.9751, Val Acc: 60.3%, Time(s): 154.46
# Epoch [76/100], Loss: 1.0030, Time (s): 156
# Epoch [76/100], Val Loss: 0.9731, Val Acc: 60.4%, Time(s): 157.77
# Epoch [77/100], Loss: 1.0022, Time (s): 159
# Epoch [77/100], Val Loss: 0.9723, Val Acc: 60.4%, Time(s): 160.95
# Epoch [78/100], Loss: 1.0014, Time (s): 162
# Epoch [78/100], Val Loss: 0.9753, Val Acc: 60.3%, Time(s): 164.18
# Epoch [79/100], Loss: 1.0006, Time (s): 166
# Epoch [79/100], Val Loss: 0.9733, Val Acc: 60.3%, Time(s): 168.19
# Epoch [80/100], Loss: 0.9998, Time (s): 170
# Epoch [80/100], Val Loss: 0.9716, Val Acc: 60.4%, Time(s): 171.45
# Epoch [81/100], Loss: 0.9990, Time (s): 173
# Epoch [81/100], Val Loss: 0.9714, Val Acc: 60.4%, Time(s): 174.77
# Epoch [82/100], Loss: 0.9983, Time (s): 176
# Epoch [82/100], Val Loss: 0.9794, Val Acc: 60.1%, Time(s): 178.35
# Epoch [83/100], Loss: 0.9976, Time (s): 180
# Epoch [83/100], Val Loss: 0.9719, Val Acc: 60.4%, Time(s): 181.94
# Epoch [84/100], Loss: 0.9969, Time (s): 183
# Epoch [84/100], Val Loss: 0.9731, Val Acc: 60.4%, Time(s): 185.34
# Epoch [85/100], Loss: 0.9962, Time (s): 187
# Epoch [85/100], Val Loss: 0.9686, Val Acc: 60.5%, Time(s): 188.80
# Epoch [86/100], Loss: 0.9955, Time (s): 191
# Epoch [86/100], Val Loss: 0.9727, Val Acc: 60.3%, Time(s): 192.91
# Epoch [87/100], Loss: 0.9949, Time (s): 194
# Epoch [87/100], Val Loss: 0.9724, Val Acc: 60.5%, Time(s): 196.39
# Epoch [88/100], Loss: 0.9942, Time (s): 198
# Epoch [88/100], Val Loss: 0.9738, Val Acc: 60.3%, Time(s): 199.88
# Epoch [89/100], Loss: 0.9936, Time (s): 202
# Epoch [89/100], Val Loss: 0.9671, Val Acc: 60.6%, Time(s): 204.12
# Epoch [90/100], Loss: 0.9929, Time (s): 206
# Epoch [90/100], Val Loss: 0.9679, Val Acc: 60.6%, Time(s): 207.69
# Epoch [91/100], Loss: 0.9922, Time (s): 209
# Epoch [91/100], Val Loss: 0.9688, Val Acc: 60.6%, Time(s): 211.29
# Epoch [92/100], Loss: 0.9916, Time (s): 213
# Epoch [92/100], Val Loss: 0.9745, Val Acc: 60.3%, Time(s): 215.42
# Epoch [93/100], Loss: 0.9909, Time (s): 217
# Epoch [93/100], Val Loss: 0.9685, Val Acc: 60.6%, Time(s): 219.20
# Epoch [94/100], Loss: 0.9902, Time (s): 221
# Epoch [94/100], Val Loss: 0.9706, Val Acc: 60.5%, Time(s): 222.90
# Epoch [95/100], Loss: 0.9897, Time (s): 225
# Epoch [95/100], Val Loss: 0.9692, Val Acc: 60.6%, Time(s): 226.83
# Epoch [96/100], Loss: 0.9891, Time (s): 229
# Epoch [96/100], Val Loss: 0.9748, Val Acc: 60.4%, Time(s): 230.81
# Epoch [97/100], Loss: 0.9886, Time (s): 232
# Epoch [97/100], Val Loss: 0.9653, Val Acc: 60.7%, Time(s): 234.59
# Epoch [98/100], Loss: 0.9880, Time (s): 236
# Epoch [98/100], Val Loss: 0.9693, Val Acc: 60.5%, Time(s): 238.45
# Epoch [99/100], Loss: 0.9875, Time (s): 241
# Epoch [99/100], Val Loss: 0.9674, Val Acc: 60.6%, Time(s): 242.68
# Epoch [100/100], Loss: 0.9869, Time (s): 244
# Epoch [100/100], Val Loss: 0.9646, Val Acc: 60.7%, Time(s): 246.55

# %% [markdown]
# ### 6.3 [1.0pt] [Type 3]
#
# The validation error of Transposed at $25^{th}$ epoch is smaller.
#
# | $25^{th}$ epoch  | Val Loss | Val Acc |
# |------------------|----------|---------|
# | PoolUpsampleNet  | 1.5877   | 41.1%   |
# | ConvTransposeNet | 1.1539   | 54.9%   |
# | UNet       | 1.0654   | 58.2%   |
#
# UNet indeed performs better than the previous two models in validation loss and accuracy. Qualitatively, the colored images by UNet is not only sharper at edges, but looks more authentic.
#
# Comparing to the ConvTransposeNet, adding skip connections helps with validation loss and accuracy.
#
# Experimental answers from ChatGPT:
#
# ![image.png](data:image/png;base64,...)
